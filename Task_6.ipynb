# %% [markdown]
# ## Данные
#
# Данные в [архиве](https://drive.google.com/file/d/15o7fdxTgndoy6K-e7g8g1M2-bOOwqZPl/view?usp=sharing). В нём два файла:
# - `news_train.txt` тестовое множество
# - `news_test.txt` тренировочное множество
#
# С некоторых новостных сайтов были загружены тексты новостей за период  несколько лет, причем каждая новость принаделжит к какой-то рубрике: `science`, `style`, `culture`, `life`, `economics`, `business`, `travel`, `forces`, `media`, `sport`.
#
# В каждой строке файла содержится метка рубрики, заголовок новостной статьи и сам текст статьи, например:
#
# >    **sport**&nbsp;&lt;tab&gt;&nbsp;**Сборная Канады по хоккею разгромила чехов**&nbsp;&lt;tab&gt;&nbsp;**Сборная Канады по хоккею крупно об...**

# %% [markdown]
# # Задача
#
# 1. Обработать данные, получив для каждого текста набор токенов
# Обработать токены с помощью (один вариант из трех):
#     - pymorphy2
#     - русского [snowball стеммера](https://www.nltk.org/howto/stem.html)
#     - [SentencePiece](https://github.com/google/sentencepiece) или [Huggingface Tokenizers](https://github.com/huggingface/tokenizers)
#
#
# 2. Обучить word embeddings (fastText, word2vec, gloVe) на тренировочных данных. Можно использовать [gensim](https://radimrehurek.com/gensim/models/word2vec.html) . Продемонстрировать семантические ассоциации.
#
# 3. Реализовать алгоритм классификации документа по категориям, посчитать точность на тестовых данных, подобрать гиперпараметры. Метод векторизации выбрать произвольно - можно использовать $tf-idf$ с понижением размерности (см. scikit-learn), можно использовать обученные на предыдущем шаге векторные представления, можно использовать [предобученные модели](https://rusvectores.org/ru/models/). Имейте ввиду, что простое "усреднение" токенов в тексте скорее всего не даст положительных результатов. Нужно реализовать два алгоритмов из трех:
#      - SVM
#      - наивный байесовский классификатор
#      - логистическая регрессия
#
#
# 4.* Реализуйте классификацию с помощью нейросетевых моделей. Например [RuBERT](http://docs.deeppavlov.ai/en/master/features/models/bert.html) или [ELMo](https://rusvectores.org/ru/models/).

# %%
import pandas as pd
import gensim
import pymorphy2
from pymorphy2 import tokenizers
# Out:
# c:\Users\Elizaveta\Classifications_2021\venv\lib\site-packages\gensim\utils.py:1197: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
df_train = pd.read_csv('data/news_train.txt',sep='\t', header = None)

# %%
def clear_words(text):
    result = []
    for token in text:
        if (token.isalpha() or token.isdigit()) and len(token) > 2:
            result.append(token.lower())
    return result

# %%
df_train['words'] = df_train[2].apply(lambda x: tokenizers.simple_word_tokenize(x))
df_train['clean_words'] = df_train['words'].apply(lambda x: clear_words(x))

# %%
wtw = gensim.models.Word2Vec(sentences=df_train.clean_words.values.tolist(), min_count=1)

print(wtw['вирджиния'])
wtw.wv.similar_by_word('спорт')
# Out:
# [ 0.07006904 -0.08183089  0.05295759 -0.12090743 -0.04559543 -0.06939719
#   0.09590948 -0.08637927 -0.05225879 -0.19005145 -0.03449963 -0.19282378
#  -0.15321656 -0.02717497  0.0497912   0.1326137  -0.02787533 -0.00689011
#   0.24356756  0.03049645  0.08533127  0.17156357 -0.10753623 -0.22629741
#   0.12937261  0.15628245  0.20868163 -0.0087557  -0.05961137  0.18353494
#  -0.08789812  0.10142672 -0.10274352 -0.08628326 -0.15028152  0.03478947
#   0.05092376  0.05828741 -0.0691881   0.0778143   0.03327446  0.17047513
#   0.0789312  -0.11953027 -0.22334813 -0.0633193   0.00250805  0.05873582
#  -0.04054797  0.01446224  0.11731263  0.3121611   0.07406072 -0.2355761
#   0.09579952 -0.20485735  0.04951693  0.1021158  -0.05489077  0.01147523
#   0.05040554  0.18772642 -0.04129612 -0.05467477  0.02815236 -0.06677635
#  -0.07669879  0.00670338  0.00472577  0.00804861  0.01940037  0.15781611
#   0.14274769  0.06260297  0.00940195  0.04723461 -0.00186741  0.16366167
#   0.20602639  0.0995039  -0.14652112 -0.19202656  0.40316933  0.08281554
#  -0.00650906  0.07109131  0.1423838  -0.10029916 -0.02889034  0.03092788
#  -0.02373493  0.19769634 -0.28562343 -0.02053229 -0.11871678 -0.03402425
#  -0.08707815 -0.11013991 -0.01596576 -0.13750347]
# c:\Users\Elizaveta\Classifications_2021\venv\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   This is separate from the ipykernel package so we can avoid doing imports until
# [('советский', 0.9735555052757263),
#  ('bild', 0.932914137840271),
#  ('телеканал', 0.926334798336029),
#  ('архангельска', 0.9195427894592285),
#  ('виталием', 0.9191847443580627),
#  ('радиостанция', 0.917327880859375),
#  ('радио', 0.9161995649337769),
#  ('русская', 0.9158331155776978),
#  ('прямом', 0.9108662009239197),
#  ('телеканалу', 0.9066583514213562)]

# %%
themes = list(set(df_train[0].values))
print("Все темы - лейблы", themes)
# Out:
# Все темы - лейблы ['culture', 'travel', 'style', 'media', 'life', 'sport', 'science', 'forces', 'business', 'economics']

# %%
def themes_dist(themes, df):
    res_list = dict()
    for i in themes:
        res_list[i] = 0
    list_thems = df_train[0].values
    for i in list_thems:
        res_list[i] += 1
    for i in themes:
        res_list[i] /= len(list_thems)
    return res_list

def words_dist(words, themes, df):
    res_list = dict()
    for i in themes:
        for j in words:
            res_list[(i, j)] = 0
    
    list_thems = df_train[0].values.tolist()
    list_words = df_train.clean_words.tolist()
    count = dict()
    for i in themes:
        count[i] = 0
    for i in range(len(list_words)):
        for j in list_words[i]:
            res_list[(list_thems[i], j)] += 1
            count[list_thems[i]] += 1
    for label, feat in res_list:
        res_list[label, feat] /= count[label]
    return res_list

words_dict = list(set(wtw.wv.vocab.keys()))
distr_1 = themes_dist(themes, df_train)
distr_2 = words_dist(words_dict, themes, df_train)

distr_2
# Out:
# {('culture', 'телефонии'): 0.0,
#  ('culture', 'пленоптических'): 0.0,
#  ('culture', 'полуфиналиста'): 0.0,
#  ('culture', 'запрашивается'): 0.0,
#  ('culture', 'кларксоном'): 0.0,
#  ('culture', 'галиной'): 3.2024287219427213e-06,
#  ('culture', 'взлетные'): 3.2024287219427213e-06,
#  ('culture', 'выгоден'): 0.0,
#  ('culture', 'скипетр'): 3.2024287219427213e-06,
#  ('culture', 'hawk'): 0.0,
#  ('culture', 'адвокатам'): 3.2024287219427213e-06,
#  ('culture', 'помилована'): 0.0,
#  ('culture', 'согласовав'): 3.2024287219427213e-06,
#  ('culture', 'деметриус'): 0.0,
#  ('culture', 'венецианском'): 2.561942977554177e-05,
#  ('culture', 'инджирлик'): 0.0,
#  ('culture', 'группу'): 0.000195348152038506,
#  ('culture', 'десятицентовик'): 0.0,
#  ('culture', 'мрачность'): 0.0,
#  ('culture', 'кафельников'): 0.0,
#  ('culture', 'взять'): 4.1631573385255374e-05,
#  ('culture', 'нацбезопасности'): 0.0,
#  ('culture', 'астронавтами'): 0.0,
#  ('culture', 'веранда'): 0.0,
#  ('culture', 'модуль'): 0.0,
#  ('culture', 'яценюк'): 0.0,
#  ('culture', 'сцену'): 0.00020495543820433417,
#  ('culture', 'провисело'): 0.0,
#  ('culture', 'арестованных'): 6.404857443885443e-06,
#  ('culture', 'газону'): 0.0,
#  ('culture', 'темами'): 6.404857443885443e-06,
#  ('culture', 'противостояла'): 0.0,
#  ('culture', 'накопившийся'): 0.0,
#  ('culture', 'юбилейную'): 0.0,
#  ('culture', 'пьетро'): 6.404857443885443e-06,
#  ('culture', 'превышено'): 0.0,
#  ('culture', 'объясняя'): 1.6012143609713607e-05,
#  ('culture', 'неволю'): 0.0,
#  ('culture', 'неадекватном'): 0.0,
#  ('culture', 'cap'): 3.2024287219427213e-06,
#  ('culture', 'выполнены'): 9.607286165828164e-06,
#  ('culture', 'находившийся'): 6.404857443885443e-06,
#  ('culture', 'резенбург'): 0.0,
#  ('culture', 'сокращен'): 3.2024287219427213e-06,
#  ('culture', 'распущенными'): 0.0,
#  ('culture', 'электронвольта'): 0.0,
#  ('culture', 'жире'): 0.0,
#  ('culture', 'жестокостью'): 0.0,
#  ('culture', 'подледной'): 0.0,
#  ('culture', 'выделить'): 3.2024287219427214e-05,
#  ('culture', 'обнаружении'): 6.404857443885443e-06,
#  ('culture', 'поступлениям'): 0.0,
#  ('culture', 'аникеева'): 0.0,
#  ('culture', 'обеспечивающими'): 0.0,
#  ('culture', 'обвиненному'): 0.0,
#  ('culture', 'планирующей'): 0.0,
#  ('culture', 'чехов'): 0.0,
#  ('culture', 'стиллера'): 6.404857443885443e-06,
#  ('culture', 'роули'): 0.0,
#  ('culture', 'соэрберг'): 0.0,
#  ('culture', 'ягуар'): 0.0,
#  ('culture', 'мерфи'): 7.36558606046826e-05,
#  ('culture', 'осквернении'): 0.0,
#  ('culture', 'подкрашенной'): 0.0,
#  ('culture', 'неотложную'): 0.0,
#  ('culture', 'монастыря'): 4.1631573385255374e-05,
#  ('culture', 'апатии'): 6.404857443885443e-06,
#  ('culture', 'характерному'): 0.0,
#  ('culture', 'лидирующего'): 0.0,
#  ('culture', 'спонтанным'): 3.2024287219427213e-06,
#  ('culture', 'скандалы'): 3.2024287219427213e-06,
#  ('culture', 'соцстраха'): 0.0,
#  ('culture', 'занятости'): 3.2024287219427213e-06,
#  ('culture', 'плевал'): 3.2024287219427213e-06,
#  ('culture', 'вудман'): 0.0,
#  ('culture', 'антифишинговой'): 0.0,
#  ('culture', 'получаемую'): 0.0,
#  ('culture', 'слэмон'): 0.0,
#  ('culture', 'идентичность'): 0.0,
#  ('culture', 'проволоки'): 0.0,
#  ('culture', 'отгоняют'): 0.0,
#  ('culture', 'речевого'): 0.0,
#  ('culture', 'ивашевка'): 0.0,
#  ('culture', 'акулы'): 6.404857443885443e-06,
#  ('culture', 'выскочив'): 0.0,
#  ('culture', 'сыночек'): 6.404857443885443e-06,
#  ('culture', 'неуравновешенной'): 0.0,
#  ('culture', 'молниями'): 0.0,
#  ('culture', 'незнакомцами'): 0.0,
#  ('culture', 'vimeo'): 6.404857443885443e-06,
#  ('culture', 'rovio'): 0.0,
#  ('culture', 'израсходован'): 0.0,
#  ('culture', 'всероссийское'): 0.0,
#  ('culture', 'everybody'): 6.404857443885443e-06,
#  ('culture', 'многообещающих'): 6.404857443885443e-06,
#  ('culture', 'промежуточную'): 0.0,
#  ('culture', 'драконов'): 3.2024287219427213e-06,
#  ('culture', 'вакером'): 0.0,
#  ('culture', 'ковровскую'): 0.0,
#  ('culture', 'похолодание'): 0.0,
#  ('culture', 'сориентировался'): 0.0,
#  ('culture', 'неповиновения'): 0.0,
#  ('culture', 'бюрле'): 3.2024287219427213e-06,
#  ('culture', 'казачье'): 3.2024287219427213e-06,
#  ('culture', 'популярны'): 1.2809714887770885e-05,
#  ('culture', 'двигатели'): 0.0,
#  ('culture', 'решающей'): 0.0,
#  ('culture', 'дизелем'): 0.0,
#  ('culture', 'харьковской'): 0.0,
#  ('culture', 'sheffield'): 9.607286165828164e-06,
#  ('culture', 'межрегиональным'): 0.0,
#  ('culture', 'упоминалась'): 0.0,
#  ('culture', 'кенийцы'): 0.0,
#  ('culture', 'расин'): 0.0,
#  ('culture', '1083'): 0.0,
#  ('culture', 'несовершеннолетнюю'): 0.0,
#  ('culture', 'отдаленные'): 3.2024287219427213e-06,
#  ('culture', 'вышедшей'): 8.006071804856804e-05,
#  ('culture', 'выгуливала'): 0.0,
#  ('culture', 'впустить'): 0.0,
#  ('culture', 'родителями'): 2.241700105359905e-05,
#  ('culture', 'квятом'): 0.0,
#  ('culture', 'миллилитров'): 0.0,
#  ('culture', 'судовладельца'): 0.0,
#  ('culture', 'сайпрес'): 0.0,
#  ('culture', 'мульйо'): 0.0,
#  ('culture', 'сбитый'): 0.0,
#  ('culture', 'альбертини'): 0.0,
#  ('culture', 'сервере'): 0.0,
#  ('culture', 'спинов'): 0.0,
#  ('culture', 'преследовала'): 0.0,
#  ('culture', 'корню'): 0.0,
#  ('culture', 'сгорели'): 3.2024287219427213e-06,
#  ('culture', 'haemaphysalis'): 0.0,
#  ('culture', 'мэрии'): 1.2809714887770885e-05,
#  ('culture', 'подсчитываются'): 0.0,
#  ('culture', 'нутовое'): 0.0,
#  ('culture', 'половиной'): 4.803643082914082e-05,
#  ('culture', 'whaleship'): 6.404857443885443e-06,
#  ('culture', 'югополис'): 0.0,
#  ('culture', 'разработавший'): 0.0,
#  ('culture', 'шутливо'): 0.0,
#  ('culture', 'талантов'): 1.2809714887770885e-05,
#  ('culture', 'антаресе'): 0.0,
#  ('culture', 'физиологи'): 0.0,
#  ('culture', 'йонасом'): 3.2024287219427213e-06,
#  ('culture', 'повседневном'): 0.0,
#  ('culture', 'transat'): 0.0,
#  ('culture', 'предсерийной'): 0.0,
#  ('culture', 'bandstand'): 9.607286165828164e-06,
#  ('culture', 'виновниках'): 0.0,
#  ('culture', 'авторитета'): 3.2024287219427213e-06,
#  ('culture', 'молоток'): 0.0,
#  ('culture', 'лоукостер'): 0.0,
#  ('culture', 'капиталу'): 0.0,
#  ('culture', 'works'): 0.0,
#  ('culture', 'суперканализации'): 0.0,
#  ('culture', 'геологическом'): 0.0,
#  ('culture', 'сообщающих'): 3.2024287219427213e-06,
#  ('culture', 'проверкой'): 3.2024287219427213e-06,
#  ('culture', 'марстон'): 3.2024287219427213e-06,
#  ('culture', 'фотографировались'): 0.0,
#  ('culture', 'оружейных'): 0.0,
#  ('culture', 'мечеть'): 0.0,
#  ('culture', 'ралифа'): 0.0,
#  ('culture', 'ветеринар'): 0.0,
#  ('culture', 'iata'): 0.0,
#  ('culture', 'пропуске'): 0.0,
#  ('culture', 'арктический'): 0.0,
#  ('culture', 'подвижных'): 0.0,
#  ('culture', 'специально'): 0.00012169229143382342,
#  ('culture', 'мюнхенская'): 0.0,
#  ('culture', 'конструктора'): 1.2809714887770885e-05,
#  ('culture', 'калорийностью'): 0.0,
#  ('culture', 'телесеть'): 3.2024287219427213e-06,
#  ('culture', 'слугами'): 0.0,
#  ('culture', 'мистические'): 0.0,
#  ('culture', 'компетентность'): 0.0,
#  ('culture', 'декретного'): 0.0,
#  ('culture', 'угроз'): 9.607286165828164e-06,
#  ('culture', 'собираются'): 5.444128827302626e-05,
#  ('culture', 'магомеда'): 0.0,
#  ('culture', 'школьников'): 6.404857443885443e-06,
#  ('culture', 'аннулировала'): 3.2024287219427213e-06,
#  ('culture', 'недрах'): 0.0,
#  ('culture', 'вена'): 0.0,
#  ('culture', '683'): 6.404857443885443e-06,
#  ('culture', 'бухенвальде'): 0.0,
#  ('culture', 'президентскими'): 0.0,
#  ('culture', 'бору'): 0.0,
#  ('culture', 'годовое'): 0.0,
#  ('culture', 'миниатюрного'): 3.2024287219427213e-06,
#  ('culture', 'античности'): 0.0,
#  ('culture', 'михеева'): 0.0,
#  ('culture', 'выстоять'): 0.0,
#  ('culture', 'прицелом'): 0.0,
#  ('culture', 'аресту'): 0.0,
#  ('culture', 'разрозненных'): 0.0,
#  ('culture', 'коричневом'): 6.404857443885443e-06,
#  ('culture', 'сербки'): 0.0,
#  ('culture', 'спросят'): 0.0,
#  ('culture', 'диктаторские'): 0.0,
#  ('culture', 'росагролизинга'): 0.0,
#  ('culture', 'разоблачениям'): 0.0,
#  ('culture', 'кинозалов'): 9.607286165828164e-06,
#  ('culture', 'люсетты'): 3.2024287219427213e-06,
#  ('culture', 'побуждающие'): 0.0,
#  ('culture', 'термочувствительные'): 0.0,
#  ('culture', 'прикрытием'): 0.0,
#  ('culture', 'самоубийцам'): 0.0,
#  ('culture', 'верхувен'): 0.0,
#  ('culture', 'выберите'): 0.0,
#  ('culture', 'нарастив'): 0.0,
#  ('culture', 'балканского'): 0.0,
#  ('culture', 'чуйская'): 0.0,
#  ('culture', 'завершившим'): 0.0,
#  ('culture', 'запасных'): 0.0,
#  ('culture', 'ладони'): 0.0,
#  ('culture', 'теотерическую'): 3.2024287219427213e-06,
#  ('culture', 'гэдд'): 0.0,
#  ('culture', 'гонул'): 0.0,
#  ('culture', 'еженедельной'): 0.0,
#  ('culture', 'сравняв'): 0.0,
#  ('culture', 'задуманный'): 9.607286165828164e-06,
#  ('culture', 'глянцевых'): 0.0,
#  ('culture', 'правилах'): 0.0,
#  ('culture', 'винтажные'): 0.0,
#  ('culture', 'делающей'): 0.0,
#  ('culture', 'сакса'): 3.2024287219427213e-06,
#  ('culture', 'колебаниям'): 0.0,
#  ('culture', 'деления'): 0.0,
#  ('culture', 'культурной'): 4.803643082914082e-05,
#  ('culture', '552'): 0.0,
#  ('culture', 'наци'): 3.2024287219427213e-06,
#  ('culture', 'несырьевого'): 0.0,
#  ('culture', 'качай'): 0.0,
#  ('culture', 'термином'): 0.0,
#  ('culture', 'уличенного'): 0.0,
#  ('culture', 'уилла'): 3.2024287219427213e-06,
#  ('culture', 'реализовала'): 0.0,
#  ('culture', 'картонная'): 0.0,
#  ('culture', 'порадовать'): 0.0,
#  ('culture', 'cына'): 0.0,
#  ('culture', 'msn'): 0.0,
#  ('culture', 'ipo'): 0.0,
#  ('culture', 'соломенную'): 0.0,
#  ('culture', 'абхазию'): 0.0,
#  ('culture', 'doo'): 9.607286165828164e-06,
#  ('culture', 'руководителями'): 9.607286165828164e-06,
#  ('culture', 'приспособились'): 0.0,
#  ('culture', 'джабба'): 0.0,
#  ('culture', 'диспуту'): 0.0,
#  ('culture', 'саде'): 6.404857443885443e-06,
#  ('culture', 'сноудон'): 0.0,
#  ('culture', 'популярнейшим'): 0.0,
#  ('culture', 'воспламенению'): 0.0,
#  ('culture', 'пистонс'): 0.0,
#  ('culture', 'кузюка'): 0.0,
#  ('culture', 'развязать'): 0.0,
#  ('culture', 'обойтись'): 1.9214572331656327e-05,
#  ('culture', 'сделанным'): 9.607286165828164e-06,
#  ('culture', 'расцвета'): 3.2024287219427213e-06,
#  ('culture', 'попытавшуюся'): 3.2024287219427213e-06,
#  ('culture', 'буянившую'): 3.2024287219427213e-06,
#  ('culture', 'появилось'): 0.00011848986271188069,
#  ('culture', 'журналистом'): 1.2809714887770885e-05,
#  ('culture', 'графической'): 1.2809714887770885e-05,
#  ('culture', 'убытке'): 0.0,
#  ('culture', 'набран'): 3.2024287219427213e-06,
#  ('culture', 'модернизированы'): 0.0,
#  ('culture', 'гогом'): 3.2024287219427213e-06,
#  ('culture', 'зайцев'): 0.0,
#  ('culture', 'pedro'): 0.0,
#  ('culture', 'кристаллизовать'): 0.0,
#  ('culture', 'шумностью'): 0.0,
#  ('culture', 'краской'): 1.9214572331656327e-05,
#  ('culture', 'межэтнической'): 0.0,
#  ('culture', 'уточняло'): 0.0,
#  ('culture', 'миски'): 3.2024287219427213e-06,
#  ('culture', 'существуют'): 4.1631573385255374e-05,
#  ('culture', 'продолжающиеся'): 0.0,
#  ('culture', 'гбайт'): 0.0,
#  ('culture', 'кампаниях'): 0.0,
#  ('culture', 'пляжным'): 0.0,
#  ('culture', 'гера'): 0.0,
#  ('culture', 'освятил'): 0.0,
#  ('culture', 'штаатскапеллы'): 3.2024287219427213e-06,
#  ('culture', 'выявляли'): 0.0,
#  ('culture', 'лабута'): 3.2024287219427213e-06,
#  ('culture', 'ощутимому'): 0.0,
#  ('culture', 'reasons'): 3.2024287219427213e-06,
#  ('culture', 'коврам'): 0.0,
#  ('culture', 'ряде'): 1.2809714887770885e-05,
#  ('culture', 'кассира'): 0.0,
#  ('culture', 'theories'): 3.2024287219427213e-06,
#  ('culture', 'сленг'): 0.0,
#  ('culture', 'ракетчикам'): 0.0,
#  ('culture', 'атлетов'): 0.0,
#  ('culture', 'субкультуры'): 6.404857443885443e-06,
#  ('culture', 'сибири'): 9.607286165828164e-06,
#  ('culture', 'недоступны'): 0.0,
#  ('culture', 'беджамовым'): 0.0,
#  ('culture', 'приземлился'): 0.0,
#  ('culture', 'репарации'): 0.0,
#  ('culture', 'шахлави'): 1.2809714887770885e-05,
#  ('culture', 'провозгласившая'): 0.0,
#  ('culture', 'микрофлора'): 0.0,
#  ('culture', 'протекать'): 0.0,
#  ('culture', 'цветки'): 0.0,
#  ('culture', 'родившихся'): 0.0,
#  ('culture', 'решеток'): 0.0,
#  ('culture', 'упражнения'): 0.0,
#  ('culture', 'кирпичи'): 3.2024287219427213e-06,
#  ('culture', 'башира'): 0.0,
#  ('culture', 'огнях'): 3.2024287219427213e-06,
#  ('culture', 'москвичом'): 0.0,
#  ('culture', 'максимиха'): 0.0,
#  ('culture', 'вскрыты'): 0.0,
#  ('culture', 'выделывали'): 0.0,
#  ('culture', 'артмъюзик'): 0.0,
#  ('culture', 'обогащенного'): 0.0,
#  ('culture', 'гекдениз'): 0.0,
#  ('culture', 'suburbs'): 3.2024287219427213e-06,
#  ('culture', 'чартова'): 3.2024287219427213e-06,
#  ('culture', 'выбралась'): 0.0,
#  ('culture', 'analitic'): 0.0,
#  ('culture', 'возбуждалось'): 0.0,
#  ('culture', 'ребров'): 0.0,
#  ('culture', 'новокузнецкая'): 0.0,
#  ('culture', 'буев'): 0.0,
#  ('culture', 'сгенерируют'): 0.0,
#  ('culture', 'фудзимори'): 0.0,
#  ('culture', 'брадевальд'): 0.0,
#  ('culture', 'великолепного'): 3.2024287219427213e-06,
#  ('culture', 'полакомится'): 0.0,
#  ('culture', 'профстандартов'): 0.0,
#  ('culture', 'выплатах'): 0.0,
#  ('culture', 'несобранные'): 0.0,
#  ('culture', 'плавно'): 0.0,
#  ('culture', 'допрошена'): 0.0,
#  ('culture', 'соперничеству'): 3.2024287219427213e-06,
#  ('culture', 'двухместной'): 0.0,
#  ('culture', 'отборочными'): 3.2024287219427213e-06,
#  ('culture', 'процентным'): 0.0,
#  ('culture', 'цатра'): 3.2024287219427213e-06,
#  ('culture', 'противоположного'): 0.0,
#  ('culture', 'днями'): 1.6012143609713607e-05,
#  ('culture', 'сербу'): 0.0,
#  ('culture', 'распространителей'): 0.0,
#  ('culture', 'камера'): 1.6012143609713607e-05,
#  ('culture', 'неприличным'): 0.0,
#  ('culture', 'номинированным'): 6.404857443885443e-06,
#  ('culture', 'росгвардия'): 0.0,
#  ('culture', 'rancho'): 0.0,
#  ('culture', 'ослабили'): 0.0,
#  ('culture', 'интеллектуальных'): 3.2024287219427213e-06,
#  ('culture', 'марсианин'): 1.9214572331656327e-05,
#  ('culture', 'максимизацию'): 0.0,
#  ('culture', 'капиталъ'): 0.0,
#  ('culture', 'брэйден'): 0.0,
#  ('culture', 'airy'): 0.0,
#  ('culture', 'объявляю'): 3.2024287219427213e-06,
#  ('culture', 'qué'): 6.404857443885443e-06,
#  ('culture', 'сентябрьских'): 3.2024287219427213e-06,
#  ('culture', 'дизайнерских'): 0.0,
#  ('culture', 'вудуистов'): 0.0,
#  ('culture', 'авторучек'): 0.0,
#  ('culture', 'бычий'): 0.0,
#  ('culture', 'сочинском'): 0.0,
#  ('culture', 'следом'): 1.2809714887770885e-05,
#  ('culture', 'восточныйнаноспутник'): 0.0,
#  ('culture', 'огорчены'): 3.2024287219427213e-06,
#  ('culture', 'минимумы'): 0.0,
#  ('culture', 'сервисным'): 0.0,
#  ('culture', 'дамой'): 3.2024287219427213e-06,
#  ('culture', 'укоренилась'): 0.0,
#  ('culture', 'univision'): 3.2024287219427213e-06,
#  ('culture', 'апостол'): 0.0,
#  ('culture', 'свидетельствующих'): 0.0,
#  ('culture', 'атэс'): 3.2024287219427213e-06,
#  ('culture', 'синяки'): 0.0,
#  ('culture', 'гаражах'): 3.2024287219427213e-06,
#  ('culture', 'доставленные'): 0.0,
#  ('culture', 'raid'): 0.0,
#  ('culture', 'госсекретарь'): 3.2024287219427213e-06,
#  ('culture', 'soil'): 0.0,
#  ('culture', 'pride'): 0.0,
#  ('culture', 'умышленного'): 0.0,
#  ('culture', 'девчонки'): 3.2024287219427213e-06,
#  ('culture', 'вертолетоносных'): 0.0,
#  ('culture', 'расчищенный'): 0.0,
#  ('culture', 'внесет'): 0.0,
#  ('culture', 'supli'): 0.0,
#  ('culture', 'питтсбургом'): 0.0,
#  ('culture', '7659'): 0.0,
#  ('culture', 'cowen'): 0.0,
#  ('culture', 'бемельмансона'): 0.0,
#  ('culture', 'pax'): 0.0,
#  ('culture', 'хробат'): 0.0,
#  ('culture', 'иерусалимский'): 6.404857443885443e-06,
#  ('culture', 'участках'): 6.404857443885443e-06,
#  ('culture', 'фэйтфул'): 6.404857443885443e-06,
#  ('culture', 'исследованное'): 0.0,
#  ('culture', 'развите'): 0.0,
#  ('culture', 'жуковском'): 0.0,
#  ('culture', 'proclamation'): 0.0,
#  ('culture', 'торгуют'): 0.0,
#  ('culture', 'националистом'): 6.404857443885443e-06,
#  ('culture', 'наталья'): 4.803643082914082e-05,
#  ('culture', 'артустановкой'): 0.0,
#  ('culture', 'миграцию'): 0.0,
#  ('culture', 'гуманитарном'): 0.0,
#  ('culture', 'переделан'): 0.0,
#  ('culture', 'decoder'): 3.2024287219427213e-06,
#  ('culture', 'приватбанке'): 0.0,
#  ('culture', 'лангдейл'): 0.0,
#  ('culture', 'заложник'): 0.0,
#  ('culture', 'цифрах'): 3.2024287219427213e-06,
#  ('culture', 'женя'): 6.404857443885443e-06,
#  ('culture', 'coinjar'): 0.0,
#  ('culture', 'сидевшего'): 0.0,
#  ('culture', 'васильевской'): 6.404857443885443e-06,
#  ('culture', 'finopolis'): 0.0,
#  ('culture', 'звероподобными'): 0.0,
#  ('culture', 'ural'): 0.0,
#  ('culture', 'криптономикон'): 0.0,
#  ('culture', 'леси'): 0.0,
#  ('culture', 'проданный'): 6.404857443885443e-06,
#  ('culture', 'задач'): 2.241700105359905e-05,
#  ('culture', 'теризинозаврам'): 0.0,
#  ('culture', 'порвала'): 3.2024287219427213e-06,
#  ('culture', 'чрезмерном'): 0.0,
#  ('culture', 'остывая'): 0.0,
#  ('culture', 'рвк'): 0.0,
#  ('culture', 'тпу'): 0.0,
#  ('culture', 'флайерз'): 0.0,
#  ('culture', 'масяня'): 0.0,
#  ('culture', 'аккую'): 0.0,
#  ('culture', 'оттянем'): 0.0,
#  ('culture', 'соглашаясь'): 3.2024287219427213e-06,
#  ('culture', 'невоспалительного'): 0.0,
#  ('culture', 'рубашках'): 0.0,
#  ('culture', 'обживших'): 0.0,
#  ('culture', 'золотодобывающая'): 0.0,
#  ('culture', 'приватность'): 0.0,
#  ('culture', 'сообществах'): 0.0,
#  ('culture', 'gilbert'): 0.0,
#  ('culture', 'бешенству'): 0.0,
#  ('culture', 'вагенинген'): 0.0,
#  ('culture', 'правках'): 0.0,
#  ('culture', 'бургеры'): 0.0,
#  ('culture', 'подавляет'): 0.0,
#  ('culture', 'миниатюру'): 0.0,
#  ('culture', 'вымышленное'): 0.0,
#  ('culture', 'вествуд'): 0.0,
#  ('culture', 'леопардом'): 0.0,
#  ('culture', 'лихорадки'): 0.0,
#  ('culture', 'nox'): 3.2024287219427213e-06,
#  ('culture', 'телевизора'): 0.0,
#  ('culture', 'грушко'): 0.0,
#  ('culture', 'мурсалиев'): 0.0,
#  ('culture', 'отлететь'): 0.0,
#  ('culture', 'метильных'): 0.0,
#  ('culture', 'акустические'): 3.2024287219427213e-06,
#  ('culture', 'выдумана'): 3.2024287219427213e-06,
#  ('culture', 'bright'): 3.2024287219427213e-06,
#  ('culture', 'главе'): 5.444128827302626e-05,
#  ('culture', 'размыты'): 0.0,
#  ('culture', 'кайоде'): 0.0,
#  ('culture', 'национальностям'): 0.0,
#  ('culture', 'грозненскому'): 0.0,
#  ('culture', 'распорядились'): 0.0,
#  ('culture', 'рэтер'): 0.0,
#  ('culture', 'фонаря'): 0.0,
#  ('culture', 'современному'): 1.9214572331656327e-05,
#  ('culture', 'каньоне'): 3.2024287219427213e-06,
#  ('culture', 'сочио'): 0.0,
#  ('culture', 'randall'): 0.0,
#  ('culture', 'паралимпиадыон'): 0.0,
#  ('culture', 'применив'): 0.0,
#  ('culture', 'причалить'): 0.0,
#  ('culture', 'воробью'): 0.0,
#  ('culture', 'iuniverse'): 3.2024287219427213e-06,
#  ('culture', 'ноябре'): 0.00027540887008707405,
#  ('culture', 'раздельным'): 0.0,
#  ('culture', 'рывок'): 0.0,
#  ('culture', 'варьировался'): 0.0,
#  ('culture', 'курбатов'): 0.0,
#  ('culture', 'учебная'): 0.0,
#  ('culture', 'копполы'): 2.241700105359905e-05,
#  ('culture', 'символической'): 0.0,
#  ('culture', 'драгоценными'): 0.0,
#  ('culture', 'аочана'): 0.0,
#  ('culture', 'близкий'): 9.607286165828164e-06,
#  ('culture', 'мозгава'): 3.2024287219427213e-06,
#  ('culture', 'устриц'): 0.0,
#  ('culture', 'трейдерызагадочный'): 0.0,
#  ('culture', 'раздражать'): 9.607286165828164e-06,
#  ('culture', 'дополнили'): 0.0,
#  ('culture', 'управляемое'): 0.0,
#  ('culture', 'cayenne'): 0.0,
#  ('culture', 'брикетами'): 0.0,
#  ('culture', 'структурными'): 0.0,
#  ('culture', 'преступлениями'): 0.0,
#  ('culture', 'сибата'): 0.0,
#  ('culture', 'пресли'): 4.48340021071981e-05,
#  ('culture', 'братские'): 0.0,
#  ('culture', 'остающаяся'): 0.0,
#  ('culture', 'постепенным'): 0.0,
#  ('culture', 'нормальную'): 0.0,
#  ('culture', 'адлерском'): 0.0,
#  ('culture', 'тронула'): 0.0,
#  ('culture', 'бабаяна'): 0.0,
#  ('culture', 'бостон'): 6.404857443885443e-06,
#  ('culture', 'очистительной'): 0.0,
#  ('culture', 'манеже'): 1.9214572331656327e-05,
#  ('culture', 'платоном'): 3.2024287219427213e-06,
#  ('culture', 'таджиктелеком'): 0.0,
#  ('culture', 'беовульфе'): 3.2024287219427213e-06,
#  ('culture', 'роке'): 6.404857443885443e-06,
#  ('culture', 'гкм'): 0.0,
#  ('culture', 'влияния'): 0.0,
#  ('culture', 'криогенной'): 0.0,
#  ('culture', 'малолетние'): 0.0,
#  ('culture', 'лесников'): 0.0,
#  ('culture', 'мясных'): 3.2024287219427213e-06,
#  ('culture', 'вызванным'): 0.0,
#  ('culture', 'лейси'): 0.0,
#  ('culture', 'комитетов'): 0.0,
#  ('culture', 'поперечным'): 0.0,
#  ('culture', 'эскерханову'): 0.0,
#  ('culture', 'кинопродюсеров'): 0.0,
#  ('culture', 'качающийся'): 0.0,
#  ('culture', 'индустриальное'): 0.0,
#  ('culture', 'ослабнет'): 0.0,
#  ('culture', 'призыву'): 0.0,
#  ('culture', 'подрабатывает'): 6.404857443885443e-06,
#  ('culture', 'сигал'): 3.5226715941369934e-05,
#  ('culture', 'сведбанк'): 0.0,
#  ('culture', 'заголовка'): 3.2024287219427213e-06,
#  ('culture', 'связной'): 6.404857443885443e-06,
#  ('culture', 'symbolic'): 3.2024287219427213e-06,
#  ('culture', 'чампино'): 0.0,
#  ('culture', 'макмастера'): 0.0,
#  ('culture', 'тэймор'): 1.2809714887770885e-05,
#  ('culture', 'tengrinews'): 0.0,
#  ('culture', 'встряхнуть'): 0.0,
#  ('culture', 'самакаева'): 0.0,
#  ('culture', 'делающего'): 3.2024287219427213e-06,
#  ('culture', 'кукушкина'): 3.2024287219427213e-06,
#  ('culture', 'животное'): 3.2024287219427213e-06,
#  ('culture', 'награжден'): 3.8429144663312654e-05,
#  ('culture', 'скатина'): 0.0,
#  ('culture', 'наняли'): 0.0,
#  ('culture', 'данлэпа'): 0.0,
#  ('culture', 'загрязнять'): 0.0,
#  ('culture', 'подростку'): 0.0,
#  ('culture', 'евтушенков'): 0.0,
#  ('culture', 'вдохнуть'): 0.0,
#  ('culture', 'клавишные'): 3.2024287219427213e-06,
#  ('culture', 'пиратства'): 0.0,
#  ('culture', 'понтифика'): 3.2024287219427213e-06,
#  ('culture', 'джинн'): 0.0,
#  ('culture', 'антикризисном'): 0.0,
#  ('culture', 'рождествено'): 6.404857443885443e-06,
#  ('culture', 'основному'): 0.0,
#  ('culture', 'конкурентоспособности'): 0.0,
#  ('culture', 'благотворные'): 0.0,
#  ('culture', 'выгоняющий'): 0.0,
#  ('culture', 'available'): 3.2024287219427213e-06,
#  ('culture', 'гастрономическим'): 0.0,
#  ('culture', 'разоблачитель'): 0.0,
#  ('culture', 'отбывая'): 0.0,
#  ('culture', 'кустами'): 0.0,
#  ('culture', 'прикусом'): 0.0,
#  ('culture', 'нормымихо'): 0.0,
#  ('culture', 'онкологическое'): 3.2024287219427213e-06,
#  ('culture', 'расставленные'): 0.0,
#  ('culture', 'исключенному'): 0.0,
#  ('culture', 'инсинуациями'): 3.2024287219427213e-06,
#  ('culture', 'золотом'): 3.2024287219427213e-06,
#  ('culture', 'передрук'): 0.0,
#  ('culture', 'наркополицейские'): 0.0,
#  ('culture', 'print'): 0.0,
#  ('culture', 'обошел'): 6.404857443885443e-06,
#  ('culture', 'сьюзэн'): 3.2024287219427213e-06,
#  ('culture', 'четырехлетнее'): 0.0,
#  ('culture', 'шупбах'): 3.2024287219427213e-06,
#  ('culture', 'телеконференций'): 0.0,
#  ('culture', 'церерой'): 0.0,
#  ('culture', 'кораллах'): 0.0,
#  ('culture', 'перепрофилированию'): 0.0,
#  ('culture', 'тюлень'): 0.0,
#  ('culture', 'выстреле'): 0.0,
#  ('culture', 'транспортник'): 0.0,
#  ('culture', 'строгого'): 1.2809714887770885e-05,
#  ('culture', 'haim'): 6.404857443885443e-06,
#  ('culture', 'селлера'): 0.0,
#  ('culture', 'андорра'): 0.0,
#  ('culture', 'кинопленками'): 3.2024287219427213e-06,
#  ('culture', 'кошельковразработан'): 0.0,
#  ('culture', 'замки'): 1.2809714887770885e-05,
#  ('culture', 'едим'): 0.0,
#  ('culture', 'прилепленной'): 0.0,
#  ('culture', 'оптовая'): 0.0,
#  ('culture', 'питанием'): 0.0,
#  ('culture', 'внезапная'): 0.0,
#  ('culture', 'визах'): 0.0,
#  ('culture', 'запечатлевшие'): 0.0,
#  ('culture', 'отравление'): 3.2024287219427213e-06,
#  ('culture', 'ушениной'): 0.0,
#  ('culture', 'обанкротятся'): 0.0,
#  ('culture', 'робсона'): 3.2024287219427213e-06,
#  ('culture', 'увенчавшиеся'): 0.0,
#  ('culture', 'принесла'): 9.607286165828164e-05,
#  ('culture', 'причиненном'): 0.0,
#  ('culture', 'форексе'): 0.0,
#  ('culture', 'pour'): 0.0,
#  ('culture', 'серба'): 3.2024287219427213e-06,
#  ('culture', 'trojan'): 0.0,
#  ('culture', 'broadcast'): 3.2024287219427213e-06,
#  ('culture', 'sipri'): 0.0,
#  ('culture', 'намордника'): 0.0,
#  ('culture', 'винтовка'): 0.0,
#  ('culture', 'жертвует'): 6.404857443885443e-06,
#  ('culture', 'стемпняк'): 0.0,
#  ('culture', 'river'): 1.6012143609713607e-05,
#  ('culture', 'груненкова'): 0.0,
#  ('culture', 'powerup'): 0.0,
#  ('culture', 'cream'): 0.0,
#  ('culture', 'rienzo'): 0.0,
#  ('culture', 'сенатору'): 0.0,
#  ('culture', 'переговорного'): 0.0,
#  ('culture', 'непорочно'): 0.0,
#  ('culture', 'журналистов'): 4.1631573385255374e-05,
#  ('culture', 'twin'): 0.0,
#  ('culture', 'федотова'): 3.2024287219427213e-06,
#  ('culture', 'вознесенскому'): 3.2024287219427213e-06,
#  ('culture', 'сексуальном'): 0.0,
#  ('culture', 'перепостили'): 0.0,
#  ('culture', 'бартка'): 3.2024287219427213e-06,
#  ('culture', 'перрена'): 0.0,
#  ('culture', 'нераспространения'): 0.0,
#  ('culture', 'обновить'): 6.404857443885443e-06,
#  ('culture', 'определяя'): 0.0,
#  ('culture', 'прошептал'): 0.0,
#  ('culture', 'сменяет'): 0.0,
#  ('culture', 'рэб'): 0.0,
#  ('culture', 'злокачественную'): 0.0,
#  ('culture', 'лимитов'): 0.0,
#  ('culture', 'нефтяными'): 0.0,
#  ('culture', 'трансбалканский'): 0.0,
#  ('culture', 'горизонтальный'): 0.0,
#  ('culture', 'ленуара'): 3.2024287219427213e-06,
#  ('culture', 'нагревали'): 0.0,
#  ('culture', 'заложенной'): 0.0,
#  ('culture', 'пленницу'): 0.0,
#  ('culture', 'рассказываю'): 0.0,
#  ('culture', 'москитных'): 0.0,
#  ('culture', 'стволовыми'): 0.0,
#  ('culture', 'broadcasters'): 0.0,
#  ('culture', 'revelations'): 0.0,
#  ('culture', 'обнаруженными'): 0.0,
#  ('culture', '230539'): 0.0,
#  ('culture', 'исхожу'): 0.0,
#  ('culture', 'всероссийского'): 0.0,
#  ('culture', 'психопатии'): 0.0,
#  ('culture', 'поддержавшего'): 0.0,
#  ('culture', 'калифорнийское'): 3.2024287219427213e-06,
#  ('culture', 'зажечь'): 0.0,
#  ('culture', 'направившие'): 0.0,
#  ('culture', 'важности'): 3.2024287219427213e-06,
#  ('culture', 'импортозамещенияориентироваться'): 0.0,
#  ('culture', 'лутковской'): 0.0,
#  ('culture', 'новотроицк'): 0.0,
#  ('culture', 'книгам'): 3.2024287219427214e-05,
#  ('culture', 'статистических'): 0.0,
#  ('culture', 'хилларда'): 6.404857443885443e-06,
#  ('culture', 'рабстве'): 3.2024287219427213e-06,
#  ('culture', 'уго'): 3.2024287219427213e-06,
#  ('culture', 'всеукраинский'): 0.0,
#  ('culture', 'алкоголика'): 0.0,
#  ('culture', 'выдавливания'): 0.0,
#  ('culture', 'кульминацией'): 3.2024287219427213e-06,
#  ('culture', 'санкциям'): 0.0,
#  ('culture', 'михаэлис'): 0.0,
#  ('culture', 'кирдяпкин'): 0.0,
#  ('culture', 'распилили'): 3.2024287219427213e-06,
#  ('culture', 'никифоров'): 0.0,
#  ('culture', 'паводковыми'): 0.0,
#  ('culture', 'бедность'): 0.0,
#  ('culture', 'занимались'): 2.561942977554177e-05,
#  ('culture', 'перевыборов'): 0.0,
#  ('culture', 'джазовой'): 3.2024287219427213e-06,
#  ('culture', 'инкапсулированную'): 0.0,
#  ('culture', 'постами'): 0.0,
#  ('culture', 'доктрину'): 0.0,
#  ('culture', 'сценической'): 9.607286165828164e-06,
#  ('culture', 'значителен'): 0.0,
#  ('culture', '292'): 3.2024287219427213e-06,
#  ('culture', 'ваятелей'): 3.2024287219427213e-06,
#  ('culture', 'почеп'): 0.0,
#  ('culture', 'jif'): 0.0,
#  ('culture', 'оказываются'): 6.404857443885443e-06,
#  ('culture', 'теракта'): 1.6012143609713607e-05,
#  ('culture', 'бесо'): 0.0,
#  ('culture', 'даунинг'): 0.0,
#  ('culture', 'mathis'): 0.0,
#  ('culture', 'добавленное'): 0.0,
#  ('culture', 'перетекла'): 0.0,
#  ('culture', 'холи'): 0.0,
#  ('culture', 'iroquois'): 0.0,
#  ('culture', 'электродвижением'): 0.0,
#  ('culture', 'леонидовке'): 0.0,
#  ('culture', 'fundsfurfriends'): 0.0,
#  ('culture', 'институтов'): 3.2024287219427213e-06,
#  ('culture', 'трудовом'): 0.0,
#  ('culture', 'выборами'): 0.0,
#  ('culture', 'теплую'): 0.0,
#  ('culture', 'пятизвездочным'): 0.0,
#  ('culture', 'незакавыченной'): 3.2024287219427213e-06,
#  ('culture', 'неуплату'): 0.0,
#  ('culture', 'транзита'): 0.0,
#  ('culture', 'согласование'): 6.404857443885443e-06,
#  ('culture', 'навестила'): 0.0,
#  ('culture', 'сданной'): 0.0,
#  ('culture', 'буффона'): 0.0,
#  ('culture', 'расовая'): 0.0,
#  ('culture', 'банковским'): 3.2024287219427213e-06,
#  ('culture', 'прямоугольное'): 0.0,
#  ('culture', 'жесткокорпусные'): 0.0,
#  ('culture', 'коллективом'): 3.5226715941369934e-05,
#  ('culture', 'появившейся'): 0.0,
#  ('culture', 'окружила'): 0.0,
#  ('culture', 'сохраняющей'): 0.0,
#  ('culture', 'евзович'): 3.2024287219427213e-06,
#  ('culture', 'пуханов'): 3.2024287219427213e-06,
#  ('culture', 'содой'): 0.0,
#  ('culture', 'общегуманитарное'): 3.2024287219427213e-06,
#  ('culture', 'франсуа'): 1.9214572331656327e-05,
#  ('culture', 'zakone'): 3.2024287219427213e-06,
#  ('culture', 'потоковый'): 0.0,
#  ('culture', 'кипра'): 0.0,
#  ('culture', 'домкома'): 0.0,
#  ('culture', 'траншезачем'): 0.0,
#  ('culture', 'политические'): 3.8429144663312654e-05,
#  ('culture', 'айлен'): 0.0,
#  ('culture', 'югру'): 0.0,
#  ('culture', 'боясь'): 0.0,
#  ('culture', 'страммере'): 3.2024287219427213e-06,
#  ('culture', 'детским'): 9.607286165828164e-06,
#  ('culture', 'фигурантом'): 3.2024287219427213e-06,
#  ('culture', 'обозначения'): 0.0,
#  ('culture', 'истребителем'): 0.0,
#  ('culture', 'расписания'): 0.0,
#  ('culture', '1650'): 0.0,
#  ('culture', 'эбден'): 0.0,
#  ('culture', 'долговечность'): 0.0,
#  ('culture', 'червю'): 0.0,
#  ('culture', 'пиетета'): 3.2024287219427213e-06,
#  ('culture', 'блейк'): 3.2024287219427213e-06,
#  ('culture', 'языку'): 0.0,
#  ('culture', 'хабблом'): 0.0,
#  ('culture', 'ванных'): 3.2024287219427213e-06,
#  ('culture', 'алексея'): 0.00012809714887770886,
#  ('culture', 'несюжетным'): 0.0,
#  ('culture', 'сверхпроводящее'): 0.0,
#  ('culture', 'превращались'): 0.0,
#  ('culture', 'назвать'): 6.404857443885443e-05,
#  ('culture', 'гончарного'): 0.0,
#  ('culture', 'бедствия'): 9.607286165828164e-06,
#  ('culture', 'аргетины'): 0.0,
#  ('culture', 'манифеста'): 1.6012143609713607e-05,
#  ('culture', 'переключился'): 6.404857443885443e-06,
#  ('culture', 'издевалась'): 0.0,
#  ('culture', 'гидросамолета'): 0.0,
#  ('culture', 'акул'): 0.0,
#  ('culture', 'сатанизму'): 0.0,
#  ('culture', 'sron'): 0.0,
#  ('culture', 'британники'): 0.0,
#  ('culture', 'piggies'): 0.0,
#  ('culture', 'эксгумируют'): 3.2024287219427213e-06,
#  ('culture', 'бойда'): 9.607286165828164e-06,
#  ('culture', 'охотнику'): 0.0,
#  ('culture', 'сужая'): 0.0,
#  ('culture', 'виновного'): 0.0,
#  ('culture', 'ресифе'): 0.0,
#  ('culture', 'желать'): 0.0,
#  ('culture', 'окрестностям'): 0.0,
#  ('culture', 'twilight'): 6.404857443885443e-06,
#  ('culture', 'шашек'): 0.0,
#  ('culture', 'жарят'): 0.0,
#  ('culture', 'экспонировалось'): 3.2024287219427213e-06,
#  ('culture', 'микросотовую'): 0.0,
#  ('culture', 'филадельфией'): 0.0,
#  ('culture', 'копчения'): 0.0,
#  ('culture', 'медведям'): 0.0,
#  ('culture', 'натух'): 0.0,
#  ('culture', 'циррозом'): 0.0,
#  ('culture', 'стройкомплект'): 0.0,
#  ('culture', 'полиаминов'): 0.0,
#  ('culture', 'ломоносовского'): 3.2024287219427213e-06,
#  ('culture', 'бундестим'): 0.0,
#  ('culture', 'игроковв'): 0.0,
#  ('culture', 'попыталась'): 0.0,
#  ('culture', 'грановитую'): 3.2024287219427213e-06,
#  ('culture', 'laibach'): 6.404857443885443e-06,
#  ('culture', 'максимумах'): 0.0,
#  ('culture', 'коршуноваса'): 3.2024287219427213e-06,
#  ('culture', 'сэдлер'): 0.0,
#  ('culture', 'кэйн'): 0.0,
#  ('culture', 'разблокирован'): 0.0,
#  ('culture', 'тизерах'): 3.2024287219427213e-06,
#  ('culture', 'продалось'): 3.2024287219427213e-06,
#  ('culture', 'переустановку'): 0.0,
#  ('culture', 'нормотворчество'): 0.0,
#  ('culture', 'заболевание'): 9.607286165828164e-06,
#  ('culture', 'неограниченным'): 0.0,
#  ('culture', 'отбирают'): 0.0,
#  ('culture', 'тиба'): 0.0,
#  ('culture', 'старое'): 3.2024287219427213e-06,
#  ('culture', 'околозвездный'): 0.0,
#  ('culture', 'азиатском'): 3.2024287219427213e-06,
#  ('culture', 'wassup'): 6.404857443885443e-06,
#  ('culture', 'приехавших'): 0.0,
#  ('culture', 'малтноме'): 0.0,
#  ('culture', 'доставлены'): 6.404857443885443e-06,
#  ('culture', 'тянуло'): 0.0,
#  ('culture', 'поручено'): 6.404857443885443e-06,
#  ('culture', 'приоритетах'): 0.0,
#  ('culture', 'прелестным'): 0.0,
#  ('culture', 'киносоюз'): 9.607286165828164e-06,
#  ('culture', 'закопала'): 0.0,
#  ('culture', 'эйприл'): 3.2024287219427213e-06,
#  ('culture', 'coles'): 0.0,
#  ('culture', 'грузией'): 0.0,
#  ('culture', 'восьмиминутный'): 0.0,
#  ('culture', 'навигации'): 0.0,
#  ('culture', 'стриминговыми'): 0.0,
#  ('culture', 'энхансера'): 0.0,
#  ('culture', 'сообщавший'): 0.0,
#  ('culture', 'курском'): 0.0,
#  ('culture', 'парламентариям'): 0.0,
#  ('culture', 'австралийское'): 0.0,
#  ('culture', 'подзаконные'): 0.0,
#  ('culture', 'прибавляет'): 0.0,
#  ('culture', 'комсомолец'): 9.607286165828164e-06,
#  ('culture', 'облдумы'): 0.0,
#  ('culture', 'белякова'): 0.0,
#  ('culture', 'хаджи'): 0.0,
#  ('culture', 'заполночь'): 0.0,
#  ('culture', 'мельком'): 0.0,
#  ('culture', 'roten'): 6.404857443885443e-06,
#  ('culture', 'хамовнического'): 3.2024287219427213e-06,
#  ('culture', 'беркута'): 0.0,
#  ('culture', 'гамрлик'): 0.0,
#  ('culture', 'топовое'): 0.0,
#  ('culture', 'транссексуалам'): 0.0,
#  ('culture', 'сейшельскими'): 0.0,
#  ('culture', 'показавшему'): 0.0,
#  ('culture', 'барная'): 0.0,
#  ('culture', 'солнечный'): 1.6012143609713607e-05,
#  ('culture', 'naturenews'): 0.0,
#  ('culture', 'рассрочкой'): 0.0,
#  ('culture', 'коней'): 0.0,
#  ('culture', 'небанковская'): 0.0,
#  ('culture', 'флэшбеки'): 3.2024287219427213e-06,
#  ('culture', 'проктер'): 0.0,
#  ('culture', 'бурдиссо'): 0.0,
#  ('culture', 'тепловыделение'): 0.0,
#  ('culture', 'сельской'): 3.2024287219427213e-06,
#  ('culture', 'кутюрье'): 0.0,
#  ('culture', 'авангардистский'): 3.2024287219427213e-06,
#  ('culture', 'потребностей'): 0.0,
#  ('culture', 'единицах'): 0.0,
#  ('culture', 'трофеев'): 0.0,
#  ('culture', 'предотвращении'): 0.0,
#  ('culture', 'фстэк'): 0.0,
#  ('culture', 'вкусов'): 0.0,
#  ('culture', 'chronoscope'): 0.0,
#  ('culture', 'пунам'): 0.0,
#  ('culture', 'улучшает'): 0.0,
#  ('culture', 'гидеона'): 0.0,
#  ('culture', 'bloated'): 3.2024287219427213e-06,
#  ('culture', 'gutzon'): 0.0,
#  ('culture', 'соотнося'): 0.0,
#  ('culture', 'сдавать'): 0.0,
#  ('culture', 'пакистанские'): 0.0,
#  ('culture', 'фугу'): 0.0,
#  ('culture', 'надзор'): 0.0,
#  ('culture', 'гринпис'): 3.2024287219427213e-06,
#  ('culture', 'медоуказчиками'): 0.0,
#  ('culture', 'засек'): 0.0,
#  ('culture', 'столицах'): 0.0,
#  ('culture', 'авторству'): 3.2024287219427213e-06,
#  ('culture', 'окадзаки'): 0.0,
#  ('culture', 'капланом'): 0.0,
#  ('culture', 'бульдог'): 0.0,
#  ('culture', 'раскаявшиеся'): 3.2024287219427213e-06,
#  ('culture', 'монархов'): 0.0,
#  ('culture', 'karpeles'): 0.0,
#  ('culture', 'отберите'): 0.0,
#  ('culture', 'тоже'): 0.00012489472015576614,
#  ('culture', 'радиочастотное'): 0.0,
#  ('culture', 'разворачивался'): 3.2024287219427213e-06,
#  ('culture', 'руэл'): 0.0,
#  ('culture', 'переводчике'): 0.0,
#  ('culture', 'щвейцарец'): 0.0,
#  ('culture', 'berger'): 0.0,
#  ('culture', 'собираемых'): 3.2024287219427213e-06,
#  ('culture', 'туктамышеву'): 0.0,
#  ('culture', 'тамил'): 0.0,
#  ('culture', 'протопланета'): 0.0,
#  ('culture', 'telecel'): 0.0,
#  ('culture', 'владимировичу'): 0.0,
#  ('culture', 'пульте'): 0.0,
#  ('culture', 'foist'): 0.0,
#  ('culture', 'газе'): 0.0,
#  ('culture', 'initiative'): 0.0,
#  ('culture', 'рамками'): 0.0,
#  ('culture', 'ивлева'): 0.0,
#  ('culture', 'дезиле'): 0.0,
#  ('culture', 'бились'): 0.0,
#  ('culture', 'ссора'): 6.404857443885443e-06,
#  ('culture', 'подтасовывают'): 0.0,
#  ('culture', 'впала'): 0.0,
#  ('culture', 'молодежным'): 6.404857443885443e-06,
#  ('culture', 'унывает'): 0.0,
#  ('culture', 'способностью'): 6.404857443885443e-06,
#  ('culture', 'нецелевого'): 0.0,
#  ('culture', 'москомархитектурой'): 3.2024287219427213e-06,
#  ('culture', 'адская'): 0.0,
#  ('culture', 'серафимовича'): 0.0,
#  ('culture', 'змеей'): 0.0,
#  ('culture', 'гравитационной'): 0.0,
#  ('culture', 'hameister'): 0.0,
#  ('culture', 'компиляции'): 6.404857443885443e-06,
#  ('culture', 'venn'): 0.0,
#  ('culture', 'греют'): 0.0,
#  ('culture', 'грязным'): 0.0,
#  ('culture', 'юристы'): 9.607286165828164e-06,
#  ('culture', 'выезжаем'): 3.2024287219427213e-06,
#  ('culture', 'сенегале'): 0.0,
#  ('culture', 'длились'): 3.2024287219427213e-06,
#  ('culture', 'люксы'): 0.0,
#  ('culture', 'удерживаться'): 3.2024287219427213e-06,
#  ('culture', 'новость'): 2.561942977554177e-05,
#  ('culture', 'оборачивал'): 0.0,
#  ('culture', 'задаваемые'): 0.0,
#  ('culture', 'стенфордского'): 0.0,
#  ('culture', 'мелькающее'): 0.0,
#  ('culture', 'мемориале'): 0.0,
#  ('culture', 'перечислили'): 3.2024287219427213e-06,
#  ('culture', 'барван'): 0.0,
#  ('culture', 'электроприборов'): 0.0,
#  ('culture', 'спонсорских'): 0.0,
#  ('culture', 'расскажет'): 4.1631573385255374e-05,
#  ('culture', 'релевантность'): 0.0,
#  ('culture', 'неправомерном'): 0.0,
#  ('culture', 'wbtourlondon'): 0.0,
#  ('culture', 'кэмелбэк'): 0.0,
#  ('culture', 'ориентиру'): 0.0,
#  ('culture', 'ростовскому'): 0.0,
#  ('culture', 'рынка'): 2.561942977554177e-05,
#  ('culture', 'спортзала'): 0.0,
#  ('culture', 'via'): 0.0,
#  ('culture', 'сыктывкару'): 0.0,
#  ('culture', 'нефтегазоконденсатное'): 0.0,
#  ('culture', 'night'): 6.725100316079714e-05,
#  ('culture', 'отсылки'): 6.404857443885443e-06,
#  ('culture', 'живембиткоин'): 0.0,
#  ('culture', 'patricia'): 0.0,
#  ('culture', 'повезла'): 3.2024287219427213e-06,
#  ('culture', 'лэнсом'): 0.0,
#  ('culture', 'терапия'): 3.2024287219427213e-06,
#  ('culture', 'гиена'): 0.0,
#  ('culture', 'моноблоком'): 0.0,
#  ('culture', 'юинг'): 0.0,
#  ('culture', 'юбилейной'): 1.2809714887770885e-05,
#  ('culture', 'лоэнгрин'): 3.2024287219427213e-06,
#  ('culture', 'howard'): 0.0,
#  ('culture', 'prevention'): 0.0,
#  ('culture', 'огнеупорной'): 0.0,
#  ('culture', 'ломакса'): 6.404857443885443e-06,
#  ('culture', 'записей'): 5.444128827302626e-05,
#  ('culture', 'сын'): 0.00010568014782410981,
#  ('culture', 'обучаем'): 0.0,
#  ('culture', 'режим'): 3.2024287219427213e-06,
#  ('culture', 'узнают'): 2.561942977554177e-05,
#  ('culture', 'внебрачную'): 0.0,
#  ('culture', 'подолами'): 0.0,
#  ('culture', 'киркби'): 0.0,
#  ('culture', 'радиоимпульса'): 0.0,
#  ('culture', 'нортап'): 3.2024287219427213e-06,
#  ('culture', 'манила'): 0.0,
#  ('culture', 'оригинальную'): 6.404857443885443e-06,
#  ('culture', 'существо'): 3.2024287219427213e-06,
#  ('culture', 'spca'): 0.0,
#  ('culture', 'имуществу'): 0.0,
#  ('culture', 'зеленую'): 0.0,
#  ...}

# %%
from math import log
def classif(sentence, classes, prob):
    return max(classes.keys(),              # calculate argmax(-log(C|O))
        key = lambda cl: -log(classes[cl]) + sum(-log(prob.get((cl,feat), 0) + 10**(-10), 10**(-10)) for feat in sentence))

# %%
reses_train = []
clean_words = df_train.clean_words.values.tolist()
for i in range(len(clean_words)):
    reses_train.append([classif(clean_words[i], distr_1, distr_2), df_train[0].values.tolist()[i]])
    
right_count = 0
for i in reses_train:
    if (i[0] == i[1]):
        right_count += 1
print("Наивный Байессовский классификатор на обучающих данных", right_count / len(reses_train))
# Out:
# Наивный Байессовский классификатор на обучающих данных 0.9946

# %%
df_test = pd.read_csv('data/news_test.txt',sep='\t', header = None)
df_test['tokens'] = df_test[2].apply(lambda x: tokenizers.simple_word_tokenize(x))
df_test['clean_words'] = df_test['tokens'].apply(lambda x: clear_words(x))

# %%
reses_test = []
clean_words = df_test.clean_words.values.tolist()
for i in range(len(clean_words)):
    reses_test.append([classif(clean_words[i], distr_1, distr_2), df_test[0].values.tolist()[i]])

right_count = 0
for i in reses_test:
    if (i[0] == i[1]):
        right_count += 1
print("Наивный Байессовский классификатор на тестовых данных", right_count / len(reses_test))
# Out:
# Наивный Байессовский классификатор на тестовых данных 0.8426666666666667

# %%
num_vocab = wtw.wv.vocab.copy()
for i, key in enumerate(num_vocab):
    num_vocab[key] = i
num_vocab_themes = dict()
for i, k in enumerate(themes):
    num_vocab_themes[k] = i

# %%
import numpy as np

def get_vector(sentence):
    res = [0] * len(num_vocab)
    for i in sentence:
        if (num_vocab.get(i,0)) != 0:
            res[num_vocab[i]]+= 1
    new_res = []
    calls = 0
    summa = 0
    for i in res:
        calls += 1
        summa += i
        if (calls == 100):
            calls = 0
            new_res.append(summa)
            summa = 0
    v = np.array(new_res)
    normalized_v = v/(np.linalg.norm(v) + 0.00000001)
    return normalized_v.tolist()

# %%
XXX = []
for i in df_train.clean_words.values:
    XXX.append(get_vector(i))
YYY = []
for i in df_train[0].values:
    YYY.append(num_vocab_themes[i])

# %%
from sklearn import svm
print(np.any(np.isnan(XXX)))
print(np.all(np.isfinite(XXX)))
svmMy = svm.SVC(kernel='rbf', gamma=5.)
svmMy.fit(XXX, YYY)
# Out:
# False
# True
# SVC(gamma=5.0)

# %%
XXX_test = []
for i in df_test.clean_words.values:
    XXX_test.append(get_vector(i))
YYY_test = []
for i in df_test[0].values:
    YYY_test.append(num_vocab_themes[i])

# %%
counter = 0
tmp = df_test[0].values
tmp2 = df_test.clean_words.values
for i in range(len(tmp)):
    if (num_vocab_themes[tmp[i]] == svmMy.predict([get_vector(tmp2[i])])[0]):
        counter += 1
print(counter / len(tmp))
# Out:
# 0.696

# %%
import torch
from transformers import AutoTokenizer, AutoModel
tokenizer = AutoTokenizer.from_pretrained("cointegrated/rubert-tiny")
model = AutoModel.from_pretrained("cointegrated/rubert-tiny")
# model.cuda()  # uncomment it if you have a GPU

def embed_bert_cls(text, model, tokenizer):
    t = tokenizer(text, padding=True, truncation=True, return_tensors='pt')
    with torch.no_grad():
        model_output = model(**{k: v.to(model.device) for k, v in t.items()})
    embeddings = model_output.last_hidden_state[:, 0, :]
    embeddings = torch.nn.functional.normalize(embeddings)
    return embeddings[0].cpu().numpy()
# Out:
# Some weights of the model checkpoint at cointegrated/rubert-tiny were not used when initializing BertModel: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.decoder.weight', 'cls.seq_relationship.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
XXX_train_rubert = []
for i in df_train[2].values:
    XXX_train_rubert.append(embed_bert_cls(i, model, tokenizer))
YYY_train_rubert = []
for i in df_train[0].values:
    YYY_train_rubert.append(num_vocab_themes[i])

# %%
XXX_test_rubert = []
for i in df_test[2].values:
    XXX_test_rubert.append(embed_bert_cls(i, model, tokenizer))
YYY_test_rubert = []
for i in df_test[0].values:
    YYY_test_rubert.append(num_vocab_themes[i])

# %%
from sklearn import svm
print(np.any(np.isnan(XXX_train_rubert)))
print(np.all(np.isfinite(XXX_train_rubert)))
print(len(XXX_train_rubert))
svmMy_rubert = svm.SVC(kernel='rbf', gamma=5.)
svmMy_rubert.fit(XXX_train_rubert, YYY_train_rubert)
# Out:
# False
# True
# 15000
# SVC(gamma=5.0)

# %%
counter = 0
for i in range(len(XXX_test_rubert)):
    if (YYY_test_rubert[i] == svmMy_rubert.predict([XXX_test_rubert[i]])[0]):
        counter += 1
print(counter / len(tmp))
# Out:
# 0.8393333333333334
